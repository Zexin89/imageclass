# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:44, 3.83MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    print(x.shape)
    print(x.dtype)
    y=x/255
    print(y.dtype)
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# (34, 32, 32, 3)
# int64
# float64
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    """
    # TODO: Implement Function
    onehot=np.zeros([len(x),10],dtype=int)
    for i in range(len(x)):
        onehot[i][x[i]]=1
    onehotencode = onehot
    """
    return np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)
# Out:
# (9000, 32, 32, 3)
# uint8
# float64
# (9000, 32, 32, 3)
# uint8
# float64
# (9000, 32, 32, 3)
# uint8
# float64
# (9000, 32, 32, 3)
# uint8
# float64
# (9000, 32, 32, 3)
# uint8
# float64
# (5000, 32, 32, 3)
# uint8
# float64
# (10000, 32, 32, 3)
# uint8
# float64

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name="x")
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, shape=[None, n_classes], name="y")
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
    # 1 Create the weight and bias using conv_ksize, conv_num_outputs and the shape of x_tensor. 
    
    transform_to_int=int(x_tensor.shape[3])

    print(x_tensor.shape)
    
    weight_shape = (conv_ksize[0], conv_ksize[1], transform_to_int, conv_num_outputs)

    print(weight_shape)
    
    F_W = tf.Variable(tf.truncated_normal(weight_shape, mean=0.0, stddev=0.1))
    
    
    F_b = tf.Variable(tf.zeros(conv_num_outputs))
    
    
    strides = [1, conv_strides[0], conv_strides[1], 1]

    
    # 2 Apply a convolution to x_tensor using weight and conv_strides. Add bias
    
    conv = tf.nn.conv2d(x_tensor, F_W, strides, 'SAME') + F_b
    
    # 3 Add a nonlinear activation to the convolution.
    
    conv_afterReLU = tf.nn.relu(conv)
    
    # 4 Apply Max Pooling using pool_ksize and pool_strides.
      
    ksize = [1, pool_ksize[0], pool_ksize[1], 1]
    
    strides = [1, pool_strides[0], pool_strides[1], 1]
    
    conv_afterPOOL = tf.nn.max_pool(conv_afterReLU, ksize, strides, 'SAME')
    
    return conv_afterPOOL 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# (?, 32, 32, 5)
# (2, 2, 5, 10)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    x = np.prod(shape[1:])
    Flatten_tensor = tf.reshape(x_tensor, [-1, x])
    return Flatten_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    weight_shape = (int(x_tensor.shape[1]), num_outputs)
    
    Weights = tf.Variable(tf.truncated_normal(weight_shape, mean=0.0, stddev=0.1))
    
    bias = np.zeros(num_outputs)

    fc = tf.matmul(x_tensor, Weights)
    
    fc = tf.add(fc, bias)
    
    fc = tf.nn.relu(fc)
    
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight_shape = (int(x_tensor.shape[1]), num_outputs)
    
    Weights = tf.Variable(tf.truncated_normal(weight_shape, mean=0.0, stddev=0.1))
    
    bias = np.zeros(num_outputs)

    output = tf.matmul(x_tensor, Weights)
    
    output = tf.add(output, bias)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_num_outputs = 40
    conv_ksize = (4,4)
    conv_strides = (1,1)
    pool_ksize = (2,2)
    pool_strides = (2,2) 
    x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    num_outputs = 40
    x = fully_conn(x, num_outputs)
    x = fully_conn(x, 20)
    x = tf.nn.dropout(x, keep_prob)
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    nclass = 10
    f = output(x, nclass)
    
    # TODO: return output
    return f


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (?, 32, 32, 3)
# (4, 4, 3, 40)
# (?, 16, 16, 40)
# (4, 4, 40, 40)
# (?, 8, 8, 40)
# (4, 4, 40, 40)
# (?, 32, 32, 3)
# (4, 4, 3, 40)
# (?, 16, 16, 40)
# (4, 4, 40, 40)
# (?, 8, 8, 40)
# (4, 4, 40, 40)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
            x: feature_batch,
            y: label_batch,
            keep_prob: keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    #Finding loss with cost function
    loss = session.run(cost, feed_dict = {x: feature_batch, y: label_batch, keep_prob: 1.0})
    #Finding accuracy with accuracy function
    validation_accuracy = session.run(accuracy, feed_dict = {x: valid_features, y: valid_labels, keep_prob: 1.0})
    #Printing loss and validation_accuracy
    print('Loss: {:>1.4f}       Validation Accuracy: {:1.6f}'.format(loss, validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 2048
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.2871       Validation Accuracy: 0.148600
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.2611       Validation Accuracy: 0.185000
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2.2185       Validation Accuracy: 0.213000
# Epoch  4, CIFAR-10 Batch 1:  Loss: 2.1582       Validation Accuracy: 0.197000
# Epoch  5, CIFAR-10 Batch 1:  Loss: 2.0959       Validation Accuracy: 0.247600
# Epoch  6, CIFAR-10 Batch 1:  Loss: 2.0482       Validation Accuracy: 0.267600
# Epoch  7, CIFAR-10 Batch 1:  Loss: 2.0038       Validation Accuracy: 0.296200
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.9595       Validation Accuracy: 0.310000
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.9299       Validation Accuracy: 0.316200
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.8911       Validation Accuracy: 0.337600
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.8524       Validation Accuracy: 0.345200
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.8376       Validation Accuracy: 0.360000
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.8103       Validation Accuracy: 0.344200
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.7777       Validation Accuracy: 0.372800
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.7810       Validation Accuracy: 0.354000
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.7454       Validation Accuracy: 0.382600
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.7028       Validation Accuracy: 0.378200
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.6865       Validation Accuracy: 0.400600
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.7019       Validation Accuracy: 0.381200
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.6797       Validation Accuracy: 0.388000
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.6498       Validation Accuracy: 0.389200
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.6170       Validation Accuracy: 0.401400
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.6009       Validation Accuracy: 0.414000
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.5887       Validation Accuracy: 0.421400
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.5528       Validation Accuracy: 0.428800
# Epoch 26, CIFAR-10 Batch 1:  Loss: 1.5668       Validation Accuracy: 0.411000
# Epoch 27, CIFAR-10 Batch 1:  Loss: 1.5463       Validation Accuracy: 0.435800
# Epoch 28, CIFAR-10 Batch 1:  Loss: 1.5434       Validation Accuracy: 0.418000
# Epoch 29, CIFAR-10 Batch 1:  Loss: 1.5336       Validation Accuracy: 0.437200
# Epoch 30, CIFAR-10 Batch 1:  Loss: 1.5104       Validation Accuracy: 0.430400
# Epoch 31, CIFAR-10 Batch 1:  Loss: 1.4817       Validation Accuracy: 0.436400
# Epoch 32, CIFAR-10 Batch 1:  Loss: 1.4537       Validation Accuracy: 0.444000
# Epoch 33, CIFAR-10 Batch 1:  Loss: 1.4519       Validation Accuracy: 0.445800
# Epoch 34, CIFAR-10 Batch 1:  Loss: 1.4380       Validation Accuracy: 0.453000
# Epoch 35, CIFAR-10 Batch 1:  Loss: 1.4281       Validation Accuracy: 0.447200
# Epoch 36, CIFAR-10 Batch 1:  Loss: 1.4106       Validation Accuracy: 0.458000
# Epoch 37, CIFAR-10 Batch 1:  Loss: 1.3900       Validation Accuracy: 0.459600
# Epoch 38, CIFAR-10 Batch 1:  Loss: 1.3826       Validation Accuracy: 0.461000
# Epoch 39, CIFAR-10 Batch 1:  Loss: 1.3759       Validation Accuracy: 0.461200
# Epoch 40, CIFAR-10 Batch 1:  Loss: 1.3461       Validation Accuracy: 0.471200
# Epoch 41, CIFAR-10 Batch 1:  Loss: 1.3615       Validation Accuracy: 0.456600
# Epoch 42, CIFAR-10 Batch 1:  Loss: 1.3287       Validation Accuracy: 0.477400
# Epoch 43, CIFAR-10 Batch 1:  Loss: 1.3163       Validation Accuracy: 0.471200
# Epoch 44, CIFAR-10 Batch 1:  Loss: 1.3602       Validation Accuracy: 0.443000
# Epoch 45, CIFAR-10 Batch 1:  Loss: 1.3136       Validation Accuracy: 0.473600
# Epoch 46, CIFAR-10 Batch 1:  Loss: 1.2726       Validation Accuracy: 0.464600
# Epoch 47, CIFAR-10 Batch 1:  Loss: 1.2641       Validation Accuracy: 0.476200
# Epoch 48, CIFAR-10 Batch 1:  Loss: 1.2444       Validation Accuracy: 0.487600
# Epoch 49, CIFAR-10 Batch 1:  Loss: 1.2517       Validation Accuracy: 0.481200
# Epoch 50, CIFAR-10 Batch 1:  Loss: 1.2346       Validation Accuracy: 0.491800
# Epoch 51, CIFAR-10 Batch 1:  Loss: 1.2418       Validation Accuracy: 0.478600
# Epoch 52, CIFAR-10 Batch 1:  Loss: 1.2114       Validation Accuracy: 0.486000
# Epoch 53, CIFAR-10 Batch 1:  Loss: 1.2616       Validation Accuracy: 0.461000
# Epoch 54, CIFAR-10 Batch 1:  Loss: 1.1890       Validation Accuracy: 0.495000
# Epoch 55, CIFAR-10 Batch 1:  Loss: 1.1794       Validation Accuracy: 0.495000
# Epoch 56, CIFAR-10 Batch 1:  Loss: 1.1822       Validation Accuracy: 0.486600
# Epoch 57, CIFAR-10 Batch 1:  Loss: 1.1768       Validation Accuracy: 0.491000
# Epoch 58, CIFAR-10 Batch 1:  Loss: 1.1553       Validation Accuracy: 0.496400
# Epoch 59, CIFAR-10 Batch 1:  Loss: 1.1619       Validation Accuracy: 0.493000
# Epoch 60, CIFAR-10 Batch 1:  Loss: 1.1580       Validation Accuracy: 0.493800
# Epoch 61, CIFAR-10 Batch 1:  Loss: 1.1453       Validation Accuracy: 0.490200
# Epoch 62, CIFAR-10 Batch 1:  Loss: 1.1158       Validation Accuracy: 0.500000
# Epoch 63, CIFAR-10 Batch 1:  Loss: 1.1139       Validation Accuracy: 0.497600
# Epoch 64, CIFAR-10 Batch 1:  Loss: 1.0973       Validation Accuracy: 0.507200
# Epoch 65, CIFAR-10 Batch 1:  Loss: 1.1047       Validation Accuracy: 0.498800
# Epoch 66, CIFAR-10 Batch 1:  Loss: 1.0851       Validation Accuracy: 0.506400
# Epoch 67, CIFAR-10 Batch 1:  Loss: 1.0871       Validation Accuracy: 0.499000
# Epoch 68, CIFAR-10 Batch 1:  Loss: 1.0819       Validation Accuracy: 0.517000
# Epoch 69, CIFAR-10 Batch 1:  Loss: 1.0569       Validation Accuracy: 0.506200
# Epoch 70, CIFAR-10 Batch 1:  Loss: 1.0538       Validation Accuracy: 0.511200
# Epoch 71, CIFAR-10 Batch 1:  Loss: 1.1096       Validation Accuracy: 0.479200
# Epoch 72, CIFAR-10 Batch 1:  Loss: 1.0406       Validation Accuracy: 0.510600
# Epoch 73, CIFAR-10 Batch 1:  Loss: 1.0315       Validation Accuracy: 0.514000
# Epoch 74, CIFAR-10 Batch 1:  Loss: 1.0103       Validation Accuracy: 0.515400
# Epoch 75, CIFAR-10 Batch 1:  Loss: 1.0022       Validation Accuracy: 0.521000
# Epoch 76, CIFAR-10 Batch 1:  Loss: 1.0022       Validation Accuracy: 0.519200
# Epoch 77, CIFAR-10 Batch 1:  Loss: 0.9858       Validation Accuracy: 0.520800
# Epoch 78, CIFAR-10 Batch 1:  Loss: 0.9887       Validation Accuracy: 0.520400
# Epoch 79, CIFAR-10 Batch 1:  Loss: 0.9700       Validation Accuracy: 0.523800
# Epoch 80, CIFAR-10 Batch 1:  Loss: 0.9615       Validation Accuracy: 0.529400
# Epoch 81, CIFAR-10 Batch 1:  Loss: 0.9714       Validation Accuracy: 0.514200
# Epoch 82, CIFAR-10 Batch 1:  Loss: 0.9702       Validation Accuracy: 0.524400
# Epoch 83, CIFAR-10 Batch 1:  Loss: 1.0437       Validation Accuracy: 0.479000
# Epoch 84, CIFAR-10 Batch 1:  Loss: 0.9788       Validation Accuracy: 0.522200
# Epoch 85, CIFAR-10 Batch 1:  Loss: 1.0003       Validation Accuracy: 0.515400
# Epoch 86, CIFAR-10 Batch 1:  Loss: 0.9419       Validation Accuracy: 0.523800
# Epoch 87, CIFAR-10 Batch 1:  Loss: 0.9346       Validation Accuracy: 0.517600
# Epoch 88, CIFAR-10 Batch 1:  Loss: 0.9225       Validation Accuracy: 0.527200
# Epoch 89, CIFAR-10 Batch 1:  Loss: 0.9145       Validation Accuracy: 0.524400
# Epoch 90, CIFAR-10 Batch 1:  Loss: 0.9187       Validation Accuracy: 0.523600
# Epoch 91, CIFAR-10 Batch 1:  Loss: 0.8950       Validation Accuracy: 0.526200
# Epoch 92, CIFAR-10 Batch 1:  Loss: 0.8936       Validation Accuracy: 0.533600
# Epoch 93, CIFAR-10 Batch 1:  Loss: 0.8991       Validation Accuracy: 0.523800
# Epoch 94, CIFAR-10 Batch 1:  Loss: 0.8716       Validation Accuracy: 0.534200
# Epoch 95, CIFAR-10 Batch 1:  Loss: 0.8856       Validation Accuracy: 0.530000
# Epoch 96, CIFAR-10 Batch 1:  Loss: 0.8893       Validation Accuracy: 0.522400
# Epoch 97, CIFAR-10 Batch 1:  Loss: 0.8806       Validation Accuracy: 0.523000
# Epoch 98, CIFAR-10 Batch 1:  Loss: 0.8746       Validation Accuracy: 0.531400
# Epoch 99, CIFAR-10 Batch 1:  Loss: 0.8395       Validation Accuracy: 0.530400
# Epoch 100, CIFAR-10 Batch 1:  Loss: 0.8326       Validation Accuracy: 0.535000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.2863       Validation Accuracy: 0.101400
# Epoch  1, CIFAR-10 Batch 2:  Loss: 2.2773       Validation Accuracy: 0.134600
# Epoch  1, CIFAR-10 Batch 3:  Loss: 2.2418       Validation Accuracy: 0.129400
# Epoch  1, CIFAR-10 Batch 4:  Loss: 2.2176       Validation Accuracy: 0.148000
# Epoch  1, CIFAR-10 Batch 5:  Loss: 2.2077       Validation Accuracy: 0.210800
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.1415       Validation Accuracy: 0.239200
# Epoch  2, CIFAR-10 Batch 2:  Loss: 2.1308       Validation Accuracy: 0.246000
# Epoch  2, CIFAR-10 Batch 3:  Loss: 2.0717       Validation Accuracy: 0.256400
# Epoch  2, CIFAR-10 Batch 4:  Loss: 2.0271       Validation Accuracy: 0.267600
# Epoch  2, CIFAR-10 Batch 5:  Loss: 2.0240       Validation Accuracy: 0.270800
# Epoch  3, CIFAR-10 Batch 1:  Loss: 1.9629       Validation Accuracy: 0.310200
# Epoch  3, CIFAR-10 Batch 2:  Loss: 1.9584       Validation Accuracy: 0.301800
# Epoch  3, CIFAR-10 Batch 3:  Loss: 1.8909       Validation Accuracy: 0.326200
# Epoch  3, CIFAR-10 Batch 4:  Loss: 1.8767       Validation Accuracy: 0.323200
# Epoch  3, CIFAR-10 Batch 5:  Loss: 1.8738       Validation Accuracy: 0.316200
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1.8361       Validation Accuracy: 0.331200
# Epoch  4, CIFAR-10 Batch 2:  Loss: 1.8141       Validation Accuracy: 0.352600
# Epoch  4, CIFAR-10 Batch 3:  Loss: 1.7637       Validation Accuracy: 0.360200
# Epoch  4, CIFAR-10 Batch 4:  Loss: 1.7282       Validation Accuracy: 0.374200
# Epoch  4, CIFAR-10 Batch 5:  Loss: 1.7876       Validation Accuracy: 0.365600
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1.7278       Validation Accuracy: 0.388600
# Epoch  5, CIFAR-10 Batch 2:  Loss: 1.7237       Validation Accuracy: 0.395000
# Epoch  5, CIFAR-10 Batch 3:  Loss: 1.6545       Validation Accuracy: 0.394600
# Epoch  5, CIFAR-10 Batch 4:  Loss: 1.6528       Validation Accuracy: 0.394600
# Epoch  5, CIFAR-10 Batch 5:  Loss: 1.7004       Validation Accuracy: 0.395800
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1.6518       Validation Accuracy: 0.389800
# Epoch  6, CIFAR-10 Batch 2:  Loss: 1.6326       Validation Accuracy: 0.430600
# Epoch  6, CIFAR-10 Batch 3:  Loss: 1.5968       Validation Accuracy: 0.416400
# Epoch  6, CIFAR-10 Batch 4:  Loss: 1.5893       Validation Accuracy: 0.424000
# Epoch  6, CIFAR-10 Batch 5:  Loss: 1.6212       Validation Accuracy: 0.411000
# Epoch  7, CIFAR-10 Batch 1:  Loss: 1.5881       Validation Accuracy: 0.428800
# Epoch  7, CIFAR-10 Batch 2:  Loss: 1.5872       Validation Accuracy: 0.431600
# Epoch  7, CIFAR-10 Batch 3:  Loss: 1.5447       Validation Accuracy: 0.427400
# Epoch  7, CIFAR-10 Batch 4:  Loss: 1.5286       Validation Accuracy: 0.435600
# Epoch  7, CIFAR-10 Batch 5:  Loss: 1.5762       Validation Accuracy: 0.429400
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.5421       Validation Accuracy: 0.434800
# Epoch  8, CIFAR-10 Batch 2:  Loss: 1.5507       Validation Accuracy: 0.450600
# Epoch  8, CIFAR-10 Batch 3:  Loss: 1.4880       Validation Accuracy: 0.436800
# Epoch  8, CIFAR-10 Batch 4:  Loss: 1.4996       Validation Accuracy: 0.445600
# Epoch  8, CIFAR-10 Batch 5:  Loss: 1.5560       Validation Accuracy: 0.420000
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.4972       Validation Accuracy: 0.439400
# Epoch  9, CIFAR-10 Batch 2:  Loss: 1.5287       Validation Accuracy: 0.454800
# Epoch  9, CIFAR-10 Batch 3:  Loss: 1.4575       Validation Accuracy: 0.454000
# Epoch  9, CIFAR-10 Batch 4:  Loss: 1.4635       Validation Accuracy: 0.440400
# Epoch  9, CIFAR-10 Batch 5:  Loss: 1.5035       Validation Accuracy: 0.454800
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.4639       Validation Accuracy: 0.468400
# Epoch 10, CIFAR-10 Batch 2:  Loss: 1.4912       Validation Accuracy: 0.466000
# Epoch 10, CIFAR-10 Batch 3:  Loss: 1.4501       Validation Accuracy: 0.449200
# Epoch 10, CIFAR-10 Batch 4:  Loss: 1.4323       Validation Accuracy: 0.464400
# Epoch 10, CIFAR-10 Batch 5:  Loss: 1.4724       Validation Accuracy: 0.469800
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.4278       Validation Accuracy: 0.484400
# Epoch 11, CIFAR-10 Batch 2:  Loss: 1.4668       Validation Accuracy: 0.482600
# Epoch 11, CIFAR-10 Batch 3:  Loss: 1.3807       Validation Accuracy: 0.475000
# Epoch 11, CIFAR-10 Batch 4:  Loss: 1.3875       Validation Accuracy: 0.472800
# Epoch 11, CIFAR-10 Batch 5:  Loss: 1.4221       Validation Accuracy: 0.476200
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.4070       Validation Accuracy: 0.470000
# Epoch 12, CIFAR-10 Batch 2:  Loss: 1.4401       Validation Accuracy: 0.479400
# Epoch 12, CIFAR-10 Batch 3:  Loss: 1.3681       Validation Accuracy: 0.478200
# Epoch 12, CIFAR-10 Batch 4:  Loss: 1.3912       Validation Accuracy: 0.470000
# Epoch 12, CIFAR-10 Batch 5:  Loss: 1.4001       Validation Accuracy: 0.487600
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.3803       Validation Accuracy: 0.479400
# Epoch 13, CIFAR-10 Batch 2:  Loss: 1.4234       Validation Accuracy: 0.483000
# Epoch 13, CIFAR-10 Batch 3:  Loss: 1.3326       Validation Accuracy: 0.492000
# Epoch 13, CIFAR-10 Batch 4:  Loss: 1.3313       Validation Accuracy: 0.491800
# Epoch 13, CIFAR-10 Batch 5:  Loss: 1.3592       Validation Accuracy: 0.495800
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.3408       Validation Accuracy: 0.506400
# Epoch 14, CIFAR-10 Batch 2:  Loss: 1.4004       Validation Accuracy: 0.494600
# Epoch 14, CIFAR-10 Batch 3:  Loss: 1.3165       Validation Accuracy: 0.501800
# Epoch 14, CIFAR-10 Batch 4:  Loss: 1.3398       Validation Accuracy: 0.488600
# Epoch 14, CIFAR-10 Batch 5:  Loss: 1.3521       Validation Accuracy: 0.497200
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.3559       Validation Accuracy: 0.493200
# Epoch 15, CIFAR-10 Batch 2:  Loss: 1.3851       Validation Accuracy: 0.491600
# Epoch 15, CIFAR-10 Batch 3:  Loss: 1.2770       Validation Accuracy: 0.504400
# Epoch 15, CIFAR-10 Batch 4:  Loss: 1.3332       Validation Accuracy: 0.490600
# Epoch 15, CIFAR-10 Batch 5:  Loss: 1.3228       Validation Accuracy: 0.508800
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.3030       Validation Accuracy: 0.510200
# Epoch 16, CIFAR-10 Batch 2:  Loss: 1.3488       Validation Accuracy: 0.513200
# Epoch 16, CIFAR-10 Batch 3:  Loss: 1.2560       Validation Accuracy: 0.514000
# Epoch 16, CIFAR-10 Batch 4:  Loss: 1.2661       Validation Accuracy: 0.514000
# Epoch 16, CIFAR-10 Batch 5:  Loss: 1.3099       Validation Accuracy: 0.510600
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.2840       Validation Accuracy: 0.511000
# Epoch 17, CIFAR-10 Batch 2:  Loss: 1.3278       Validation Accuracy: 0.520800
# Epoch 17, CIFAR-10 Batch 3:  Loss: 1.2552       Validation Accuracy: 0.523800
# Epoch 17, CIFAR-10 Batch 4:  Loss: 1.2492       Validation Accuracy: 0.521800
# Epoch 17, CIFAR-10 Batch 5:  Loss: 1.2733       Validation Accuracy: 0.513400
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.2698       Validation Accuracy: 0.508200
# Epoch 18, CIFAR-10 Batch 2:  Loss: 1.3309       Validation Accuracy: 0.503000
# Epoch 18, CIFAR-10 Batch 3:  Loss: 1.2606       Validation Accuracy: 0.515600
# Epoch 18, CIFAR-10 Batch 4:  Loss: 1.2600       Validation Accuracy: 0.515000
# Epoch 18, CIFAR-10 Batch 5:  Loss: 1.2586       Validation Accuracy: 0.522200
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.2438       Validation Accuracy: 0.523000
# Epoch 19, CIFAR-10 Batch 2:  Loss: 1.3039       Validation Accuracy: 0.529000
# Epoch 19, CIFAR-10 Batch 3:  Loss: 1.2233       Validation Accuracy: 0.525200
# Epoch 19, CIFAR-10 Batch 4:  Loss: 1.2211       Validation Accuracy: 0.515600
# Epoch 19, CIFAR-10 Batch 5:  Loss: 1.2555       Validation Accuracy: 0.522400
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.2362       Validation Accuracy: 0.526400
# Epoch 20, CIFAR-10 Batch 2:  Loss: 1.2858       Validation Accuracy: 0.530000
# Epoch 20, CIFAR-10 Batch 3:  Loss: 1.2061       Validation Accuracy: 0.533600
# Epoch 20, CIFAR-10 Batch 4:  Loss: 1.2441       Validation Accuracy: 0.522400
# Epoch 20, CIFAR-10 Batch 5:  Loss: 1.2609       Validation Accuracy: 0.526000
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.2473       Validation Accuracy: 0.522800
# Epoch 21, CIFAR-10 Batch 2:  Loss: 1.2665       Validation Accuracy: 0.531000
# Epoch 21, CIFAR-10 Batch 3:  Loss: 1.1846       Validation Accuracy: 0.535200
# Epoch 21, CIFAR-10 Batch 4:  Loss: 1.1802       Validation Accuracy: 0.542600
# Epoch 21, CIFAR-10 Batch 5:  Loss: 1.2059       Validation Accuracy: 0.537400
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.2330       Validation Accuracy: 0.531200
# Epoch 22, CIFAR-10 Batch 2:  Loss: 1.2592       Validation Accuracy: 0.540000
# Epoch 22, CIFAR-10 Batch 3:  Loss: 1.1664       Validation Accuracy: 0.541000
# Epoch 22, CIFAR-10 Batch 4:  Loss: 1.1696       Validation Accuracy: 0.544400
# Epoch 22, CIFAR-10 Batch 5:  Loss: 1.2155       Validation Accuracy: 0.528200
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.2420       Validation Accuracy: 0.522200
# Epoch 23, CIFAR-10 Batch 2:  Loss: 1.2725       Validation Accuracy: 0.524000
# Epoch 23, CIFAR-10 Batch 3:  Loss: 1.2018       Validation Accuracy: 0.520000
# Epoch 23, CIFAR-10 Batch 4:  Loss: 1.1631       Validation Accuracy: 0.544600
# Epoch 23, CIFAR-10 Batch 5:  Loss: 1.1780       Validation Accuracy: 0.542600
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.1827       Validation Accuracy: 0.545200
# Epoch 24, CIFAR-10 Batch 2:  Loss: 1.2309       Validation Accuracy: 0.541800
# Epoch 24, CIFAR-10 Batch 3:  Loss: 1.1443       Validation Accuracy: 0.547000
# Epoch 24, CIFAR-10 Batch 4:  Loss: 1.1323       Validation Accuracy: 0.555400
# Epoch 24, CIFAR-10 Batch 5:  Loss: 1.1627       Validation Accuracy: 0.555200
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.1760       Validation Accuracy: 0.549800
# Epoch 25, CIFAR-10 Batch 2:  Loss: 1.2213       Validation Accuracy: 0.534800
# Epoch 25, CIFAR-10 Batch 3:  Loss: 1.1889       Validation Accuracy: 0.519200
# Epoch 25, CIFAR-10 Batch 4:  Loss: 1.1804       Validation Accuracy: 0.527200
# Epoch 25, CIFAR-10 Batch 5:  Loss: 1.1744       Validation Accuracy: 0.537200
# Epoch 26, CIFAR-10 Batch 1:  Loss: 1.1583       Validation Accuracy: 0.551400
# Epoch 26, CIFAR-10 Batch 2:  Loss: 1.1843       Validation Accuracy: 0.550800
# Epoch 26, CIFAR-10 Batch 3:  Loss: 1.1361       Validation Accuracy: 0.544600
# Epoch 26, CIFAR-10 Batch 4:  Loss: 1.1266       Validation Accuracy: 0.557000
# Epoch 26, CIFAR-10 Batch 5:  Loss: 1.1513       Validation Accuracy: 0.542400
# Epoch 27, CIFAR-10 Batch 1:  Loss: 1.1522       Validation Accuracy: 0.547600
# Epoch 27, CIFAR-10 Batch 2:  Loss: 1.1749       Validation Accuracy: 0.551000
# Epoch 27, CIFAR-10 Batch 3:  Loss: 1.1412       Validation Accuracy: 0.533600
# Epoch 27, CIFAR-10 Batch 4:  Loss: 1.1319       Validation Accuracy: 0.540600
# Epoch 27, CIFAR-10 Batch 5:  Loss: 1.1320       Validation Accuracy: 0.557200
# Epoch 28, CIFAR-10 Batch 1:  Loss: 1.1484       Validation Accuracy: 0.552000
# Epoch 28, CIFAR-10 Batch 2:  Loss: 1.1676       Validation Accuracy: 0.558200
# Epoch 28, CIFAR-10 Batch 3:  Loss: 1.0887       Validation Accuracy: 0.563600
# Epoch 28, CIFAR-10 Batch 4:  Loss: 1.0818       Validation Accuracy: 0.563800
# Epoch 28, CIFAR-10 Batch 5:  Loss: 1.1136       Validation Accuracy: 0.555600
# Epoch 29, CIFAR-10 Batch 1:  Loss: 1.1303       Validation Accuracy: 0.552600
# Epoch 29, CIFAR-10 Batch 2:  Loss: 1.1462       Validation Accuracy: 0.551800
# Epoch 29, CIFAR-10 Batch 3:  Loss: 1.0840       Validation Accuracy: 0.562600
# Epoch 29, CIFAR-10 Batch 4:  Loss: 1.0727       Validation Accuracy: 0.564000
# Epoch 29, CIFAR-10 Batch 5:  Loss: 1.1099       Validation Accuracy: 0.548200
# Epoch 30, CIFAR-10 Batch 1:  Loss: 1.1142       Validation Accuracy: 0.561000
# Epoch 30, CIFAR-10 Batch 2:  Loss: 1.1557       Validation Accuracy: 0.552800
# Epoch 30, CIFAR-10 Batch 3:  Loss: 1.1129       Validation Accuracy: 0.548000
# Epoch 30, CIFAR-10 Batch 4:  Loss: 1.0900       Validation Accuracy: 0.555400
# Epoch 30, CIFAR-10 Batch 5:  Loss: 1.0835       Validation Accuracy: 0.563400
# Epoch 31, CIFAR-10 Batch 1:  Loss: 1.1009       Validation Accuracy: 0.559800
# Epoch 31, CIFAR-10 Batch 2:  Loss: 1.1241       Validation Accuracy: 0.562600
# Epoch 31, CIFAR-10 Batch 3:  Loss: 1.0637       Validation Accuracy: 0.566200
# Epoch 31, CIFAR-10 Batch 4:  Loss: 1.0514       Validation Accuracy: 0.572000
# Epoch 31, CIFAR-10 Batch 5:  Loss: 1.0586       Validation Accuracy: 0.570000
# Epoch 32, CIFAR-10 Batch 1:  Loss: 1.1026       Validation Accuracy: 0.565000
# Epoch 32, CIFAR-10 Batch 2:  Loss: 1.1106       Validation Accuracy: 0.568000
# Epoch 32, CIFAR-10 Batch 3:  Loss: 1.0538       Validation Accuracy: 0.570000
# Epoch 32, CIFAR-10 Batch 4:  Loss: 1.0515       Validation Accuracy: 0.571800
# Epoch 32, CIFAR-10 Batch 5:  Loss: 1.0574       Validation Accuracy: 0.572200
# Epoch 33, CIFAR-10 Batch 1:  Loss: 1.1222       Validation Accuracy: 0.541400
# Epoch 33, CIFAR-10 Batch 2:  Loss: 1.1373       Validation Accuracy: 0.553400
# Epoch 33, CIFAR-10 Batch 3:  Loss: 1.0638       Validation Accuracy: 0.559200
# Epoch 33, CIFAR-10 Batch 4:  Loss: 1.0714       Validation Accuracy: 0.555800
# Epoch 33, CIFAR-10 Batch 5:  Loss: 1.0770       Validation Accuracy: 0.566200
# Epoch 34, CIFAR-10 Batch 1:  Loss: 1.0912       Validation Accuracy: 0.565600
# Epoch 34, CIFAR-10 Batch 2:  Loss: 1.1315       Validation Accuracy: 0.549600
# Epoch 34, CIFAR-10 Batch 3:  Loss: 1.0568       Validation Accuracy: 0.567800
# Epoch 34, CIFAR-10 Batch 4:  Loss: 1.0590       Validation Accuracy: 0.556600
# Epoch 34, CIFAR-10 Batch 5:  Loss: 1.0488       Validation Accuracy: 0.572600
# Epoch 35, CIFAR-10 Batch 1:  Loss: 1.0754       Validation Accuracy: 0.566600
# Epoch 35, CIFAR-10 Batch 2:  Loss: 1.0900       Validation Accuracy: 0.561800
# Epoch 35, CIFAR-10 Batch 3:  Loss: 1.0244       Validation Accuracy: 0.583000
# Epoch 35, CIFAR-10 Batch 4:  Loss: 1.0054       Validation Accuracy: 0.577000
# Epoch 35, CIFAR-10 Batch 5:  Loss: 1.0195       Validation Accuracy: 0.580200
# Epoch 36, CIFAR-10 Batch 1:  Loss: 1.0550       Validation Accuracy: 0.574800
# Epoch 36, CIFAR-10 Batch 2:  Loss: 1.0930       Validation Accuracy: 0.563000
# Epoch 36, CIFAR-10 Batch 3:  Loss: 1.0379       Validation Accuracy: 0.579600
# Epoch 36, CIFAR-10 Batch 4:  Loss: 1.0214       Validation Accuracy: 0.580200
# Epoch 36, CIFAR-10 Batch 5:  Loss: 1.0277       Validation Accuracy: 0.578200
# Epoch 37, CIFAR-10 Batch 1:  Loss: 1.0306       Validation Accuracy: 0.578000
# Epoch 37, CIFAR-10 Batch 2:  Loss: 1.0459       Validation Accuracy: 0.574200
# Epoch 37, CIFAR-10 Batch 3:  Loss: 1.0298       Validation Accuracy: 0.572600
# Epoch 37, CIFAR-10 Batch 4:  Loss: 1.0027       Validation Accuracy: 0.580800
# Epoch 37, CIFAR-10 Batch 5:  Loss: 0.9931       Validation Accuracy: 0.583200
# Epoch 38, CIFAR-10 Batch 1:  Loss: 1.0313       Validation Accuracy: 0.576400
# Epoch 38, CIFAR-10 Batch 2:  Loss: 1.0400       Validation Accuracy: 0.574400
# Epoch 38, CIFAR-10 Batch 3:  Loss: 0.9947       Validation Accuracy: 0.585200
# Epoch 38, CIFAR-10 Batch 4:  Loss: 0.9710       Validation Accuracy: 0.583200
# Epoch 38, CIFAR-10 Batch 5:  Loss: 0.9723       Validation Accuracy: 0.582000
# Epoch 39, CIFAR-10 Batch 1:  Loss: 1.0108       Validation Accuracy: 0.581200
# Epoch 39, CIFAR-10 Batch 2:  Loss: 1.0206       Validation Accuracy: 0.585800
# Epoch 39, CIFAR-10 Batch 3:  Loss: 1.0071       Validation Accuracy: 0.577400
# Epoch 39, CIFAR-10 Batch 4:  Loss: 0.9937       Validation Accuracy: 0.572000
# Epoch 39, CIFAR-10 Batch 5:  Loss: 0.9826       Validation Accuracy: 0.582800
# Epoch 40, CIFAR-10 Batch 1:  Loss: 1.0110       Validation Accuracy: 0.574600
# Epoch 40, CIFAR-10 Batch 2:  Loss: 1.0288       Validation Accuracy: 0.580600
# Epoch 40, CIFAR-10 Batch 3:  Loss: 0.9640       Validation Accuracy: 0.593600
# Epoch 40, CIFAR-10 Batch 4:  Loss: 0.9567       Validation Accuracy: 0.586000
# Epoch 40, CIFAR-10 Batch 5:  Loss: 0.9682       Validation Accuracy: 0.579800
# Epoch 41, CIFAR-10 Batch 1:  Loss: 0.9945       Validation Accuracy: 0.584200
# Epoch 41, CIFAR-10 Batch 2:  Loss: 0.9991       Validation Accuracy: 0.583000
# Epoch 41, CIFAR-10 Batch 3:  Loss: 0.9819       Validation Accuracy: 0.580200
# Epoch 41, CIFAR-10 Batch 4:  Loss: 0.9389       Validation Accuracy: 0.593000
# Epoch 41, CIFAR-10 Batch 5:  Loss: 0.9535       Validation Accuracy: 0.585400
# Epoch 42, CIFAR-10 Batch 1:  Loss: 0.9863       Validation Accuracy: 0.588400
# Epoch 42, CIFAR-10 Batch 2:  Loss: 1.0120       Validation Accuracy: 0.579800
# Epoch 42, CIFAR-10 Batch 3:  Loss: 0.9875       Validation Accuracy: 0.568000
# Epoch 42, CIFAR-10 Batch 4:  Loss: 0.9736       Validation Accuracy: 0.575600
# Epoch 42, CIFAR-10 Batch 5:  Loss: 0.9879       Validation Accuracy: 0.567600
# Epoch 43, CIFAR-10 Batch 1:  Loss: 1.0235       Validation Accuracy: 0.562000
# Epoch 43, CIFAR-10 Batch 2:  Loss: 1.0460       Validation Accuracy: 0.572200
# Epoch 43, CIFAR-10 Batch 3:  Loss: 0.9984       Validation Accuracy: 0.589000
# Epoch 43, CIFAR-10 Batch 4:  Loss: 0.9331       Validation Accuracy: 0.591600
# Epoch 43, CIFAR-10 Batch 5:  Loss: 0.9355       Validation Accuracy: 0.584200
# Epoch 44, CIFAR-10 Batch 1:  Loss: 0.9769       Validation Accuracy: 0.575600
# Epoch 44, CIFAR-10 Batch 2:  Loss: 0.9928       Validation Accuracy: 0.585600
# Epoch 44, CIFAR-10 Batch 3:  Loss: 0.9631       Validation Accuracy: 0.584600
# Epoch 44, CIFAR-10 Batch 4:  Loss: 0.9327       Validation Accuracy: 0.590400
# Epoch 44, CIFAR-10 Batch 5:  Loss: 0.9664       Validation Accuracy: 0.567600
# Epoch 45, CIFAR-10 Batch 1:  Loss: 0.9816       Validation Accuracy: 0.581400
# Epoch 45, CIFAR-10 Batch 2:  Loss: 1.0185       Validation Accuracy: 0.576800
# Epoch 45, CIFAR-10 Batch 3:  Loss: 0.9915       Validation Accuracy: 0.586800
# Epoch 45, CIFAR-10 Batch 4:  Loss: 0.9207       Validation Accuracy: 0.600200
# Epoch 45, CIFAR-10 Batch 5:  Loss: 0.9100       Validation Accuracy: 0.596200
# Epoch 46, CIFAR-10 Batch 1:  Loss: 0.9462       Validation Accuracy: 0.589200
# Epoch 46, CIFAR-10 Batch 2:  Loss: 0.9515       Validation Accuracy: 0.589600
# Epoch 46, CIFAR-10 Batch 3:  Loss: 0.9459       Validation Accuracy: 0.587600
# Epoch 46, CIFAR-10 Batch 4:  Loss: 0.9071       Validation Accuracy: 0.597800
# Epoch 46, CIFAR-10 Batch 5:  Loss: 0.9186       Validation Accuracy: 0.586800
# Epoch 47, CIFAR-10 Batch 1:  Loss: 0.9229       Validation Accuracy: 0.594800
# Epoch 47, CIFAR-10 Batch 2:  Loss: 0.9492       Validation Accuracy: 0.588200
# Epoch 47, CIFAR-10 Batch 3:  Loss: 0.9239       Validation Accuracy: 0.594600
# Epoch 47, CIFAR-10 Batch 4:  Loss: 0.8865       Validation Accuracy: 0.595800
# Epoch 47, CIFAR-10 Batch 5:  Loss: 0.9070       Validation Accuracy: 0.593200
# Epoch 48, CIFAR-10 Batch 1:  Loss: 0.9378       Validation Accuracy: 0.588400
# Epoch 48, CIFAR-10 Batch 2:  Loss: 0.9438       Validation Accuracy: 0.591200
# Epoch 48, CIFAR-10 Batch 3:  Loss: 0.9380       Validation Accuracy: 0.597200
# Epoch 48, CIFAR-10 Batch 4:  Loss: 0.8890       Validation Accuracy: 0.604000
# Epoch 48, CIFAR-10 Batch 5:  Loss: 0.8976       Validation Accuracy: 0.592600
# Epoch 49, CIFAR-10 Batch 1:  Loss: 0.9375       Validation Accuracy: 0.586600
# Epoch 49, CIFAR-10 Batch 2:  Loss: 1.0084       Validation Accuracy: 0.565400
# Epoch 49, CIFAR-10 Batch 3:  Loss: 0.9815       Validation Accuracy: 0.584000
# Epoch 49, CIFAR-10 Batch 4:  Loss: 0.8927       Validation Accuracy: 0.600800
# Epoch 49, CIFAR-10 Batch 5:  Loss: 0.8672       Validation Accuracy: 0.603600
# Epoch 50, CIFAR-10 Batch 1:  Loss: 0.9074       Validation Accuracy: 0.598000
# Epoch 50, CIFAR-10 Batch 2:  Loss: 0.9490       Validation Accuracy: 0.584200
# Epoch 50, CIFAR-10 Batch 3:  Loss: 0.9098       Validation Accuracy: 0.601600
# Epoch 50, CIFAR-10 Batch 4:  Loss: 0.8759       Validation Accuracy: 0.604200
# Epoch 50, CIFAR-10 Batch 5:  Loss: 0.8700       Validation Accuracy: 0.602600
# Epoch 51, CIFAR-10 Batch 1:  Loss: 0.9003       Validation Accuracy: 0.602000
# Epoch 51, CIFAR-10 Batch 2:  Loss: 0.9165       Validation Accuracy: 0.603200
# Epoch 51, CIFAR-10 Batch 3:  Loss: 0.9170       Validation Accuracy: 0.601000
# Epoch 51, CIFAR-10 Batch 4:  Loss: 0.8695       Validation Accuracy: 0.607400
# Epoch 51, CIFAR-10 Batch 5:  Loss: 0.8758       Validation Accuracy: 0.594800
# Epoch 52, CIFAR-10 Batch 1:  Loss: 0.9182       Validation Accuracy: 0.598600
# Epoch 52, CIFAR-10 Batch 2:  Loss: 0.9071       Validation Accuracy: 0.601800
# Epoch 52, CIFAR-10 Batch 3:  Loss: 0.9049       Validation Accuracy: 0.595600
# Epoch 52, CIFAR-10 Batch 4:  Loss: 0.8675       Validation Accuracy: 0.603000
# Epoch 52, CIFAR-10 Batch 5:  Loss: 0.8748       Validation Accuracy: 0.588000
# Epoch 53, CIFAR-10 Batch 1:  Loss: 0.9109       Validation Accuracy: 0.597000
# Epoch 53, CIFAR-10 Batch 2:  Loss: 0.9068       Validation Accuracy: 0.603400
# Epoch 53, CIFAR-10 Batch 3:  Loss: 0.8892       Validation Accuracy: 0.607600
# Epoch 53, CIFAR-10 Batch 4:  Loss: 0.8527       Validation Accuracy: 0.603800
# Epoch 53, CIFAR-10 Batch 5:  Loss: 0.8522       Validation Accuracy: 0.604600
# Epoch 54, CIFAR-10 Batch 1:  Loss: 0.8803       Validation Accuracy: 0.605600
# Epoch 54, CIFAR-10 Batch 2:  Loss: 0.8904       Validation Accuracy: 0.600000
# Epoch 54, CIFAR-10 Batch 3:  Loss: 0.8710       Validation Accuracy: 0.605200
# Epoch 54, CIFAR-10 Batch 4:  Loss: 0.8518       Validation Accuracy: 0.600000
# Epoch 54, CIFAR-10 Batch 5:  Loss: 0.8500       Validation Accuracy: 0.600800
# Epoch 55, CIFAR-10 Batch 1:  Loss: 0.8855       Validation Accuracy: 0.610800
# Epoch 55, CIFAR-10 Batch 2:  Loss: 0.8950       Validation Accuracy: 0.602600
# Epoch 55, CIFAR-10 Batch 3:  Loss: 0.9094       Validation Accuracy: 0.589800
# Epoch 55, CIFAR-10 Batch 4:  Loss: 0.8339       Validation Accuracy: 0.607600
# Epoch 55, CIFAR-10 Batch 5:  Loss: 0.8276       Validation Accuracy: 0.610800
# Epoch 56, CIFAR-10 Batch 1:  Loss: 0.8689       Validation Accuracy: 0.610200
# Epoch 56, CIFAR-10 Batch 2:  Loss: 0.8745       Validation Accuracy: 0.607200
# Epoch 56, CIFAR-10 Batch 3:  Loss: 0.8609       Validation Accuracy: 0.603600
# Epoch 56, CIFAR-10 Batch 4:  Loss: 0.8483       Validation Accuracy: 0.600400
# Epoch 56, CIFAR-10 Batch 5:  Loss: 0.8357       Validation Accuracy: 0.600400
# Epoch 57, CIFAR-10 Batch 1:  Loss: 0.8757       Validation Accuracy: 0.602400
# Epoch 57, CIFAR-10 Batch 2:  Loss: 0.8831       Validation Accuracy: 0.606000
# Epoch 57, CIFAR-10 Batch 3:  Loss: 0.9014       Validation Accuracy: 0.597600
# Epoch 57, CIFAR-10 Batch 4:  Loss: 0.8255       Validation Accuracy: 0.611000
# Epoch 57, CIFAR-10 Batch 5:  Loss: 0.8143       Validation Accuracy: 0.613000
# Epoch 58, CIFAR-10 Batch 1:  Loss: 0.8490       Validation Accuracy: 0.612400
# Epoch 58, CIFAR-10 Batch 2:  Loss: 0.8575       Validation Accuracy: 0.608400
# Epoch 58, CIFAR-10 Batch 3:  Loss: 0.8465       Validation Accuracy: 0.609000
# Epoch 58, CIFAR-10 Batch 4:  Loss: 0.8232       Validation Accuracy: 0.606800
# Epoch 58, CIFAR-10 Batch 5:  Loss: 0.8164       Validation Accuracy: 0.606800
# Epoch 59, CIFAR-10 Batch 1:  Loss: 0.8421       Validation Accuracy: 0.606400
# Epoch 59, CIFAR-10 Batch 2:  Loss: 0.8530       Validation Accuracy: 0.608200
# Epoch 59, CIFAR-10 Batch 3:  Loss: 0.8287       Validation Accuracy: 0.614200
# Epoch 59, CIFAR-10 Batch 4:  Loss: 0.7992       Validation Accuracy: 0.615600
# Epoch 59, CIFAR-10 Batch 5:  Loss: 0.7952       Validation Accuracy: 0.608600
# Epoch 60, CIFAR-10 Batch 1:  Loss: 0.8597       Validation Accuracy: 0.607800
# Epoch 60, CIFAR-10 Batch 2:  Loss: 0.8678       Validation Accuracy: 0.597000
# Epoch 60, CIFAR-10 Batch 3:  Loss: 0.8423       Validation Accuracy: 0.606600
# Epoch 60, CIFAR-10 Batch 4:  Loss: 0.8023       Validation Accuracy: 0.613000
# Epoch 60, CIFAR-10 Batch 5:  Loss: 0.7883       Validation Accuracy: 0.612800
# Epoch 61, CIFAR-10 Batch 1:  Loss: 0.8283       Validation Accuracy: 0.610800
# Epoch 61, CIFAR-10 Batch 2:  Loss: 0.8477       Validation Accuracy: 0.608800
# Epoch 61, CIFAR-10 Batch 3:  Loss: 0.8347       Validation Accuracy: 0.614400
# Epoch 61, CIFAR-10 Batch 4:  Loss: 0.7987       Validation Accuracy: 0.611600
# Epoch 61, CIFAR-10 Batch 5:  Loss: 0.7856       Validation Accuracy: 0.613000
# Epoch 62, CIFAR-10 Batch 1:  Loss: 0.8077       Validation Accuracy: 0.617400
# Epoch 62, CIFAR-10 Batch 2:  Loss: 0.8208       Validation Accuracy: 0.611600
# Epoch 62, CIFAR-10 Batch 3:  Loss: 0.8346       Validation Accuracy: 0.615000
# Epoch 62, CIFAR-10 Batch 4:  Loss: 0.7915       Validation Accuracy: 0.608200
# Epoch 62, CIFAR-10 Batch 5:  Loss: 0.7839       Validation Accuracy: 0.612800
# Epoch 63, CIFAR-10 Batch 1:  Loss: 0.8265       Validation Accuracy: 0.613600
# Epoch 63, CIFAR-10 Batch 2:  Loss: 0.8466       Validation Accuracy: 0.606000
# Epoch 63, CIFAR-10 Batch 3:  Loss: 0.8491       Validation Accuracy: 0.606400
# Epoch 63, CIFAR-10 Batch 4:  Loss: 0.7846       Validation Accuracy: 0.609800
# Epoch 63, CIFAR-10 Batch 5:  Loss: 0.7689       Validation Accuracy: 0.613800
# Epoch 64, CIFAR-10 Batch 1:  Loss: 0.8046       Validation Accuracy: 0.614800
# Epoch 64, CIFAR-10 Batch 2:  Loss: 0.8049       Validation Accuracy: 0.615000
# Epoch 64, CIFAR-10 Batch 3:  Loss: 0.8048       Validation Accuracy: 0.620000
# Epoch 64, CIFAR-10 Batch 4:  Loss: 0.7837       Validation Accuracy: 0.615800
# Epoch 64, CIFAR-10 Batch 5:  Loss: 0.7805       Validation Accuracy: 0.607400
# Epoch 65, CIFAR-10 Batch 1:  Loss: 0.8366       Validation Accuracy: 0.595200
# Epoch 65, CIFAR-10 Batch 2:  Loss: 0.8255       Validation Accuracy: 0.610400
# Epoch 65, CIFAR-10 Batch 3:  Loss: 0.7965       Validation Accuracy: 0.618000
# Epoch 65, CIFAR-10 Batch 4:  Loss: 0.7559       Validation Accuracy: 0.620200
# Epoch 65, CIFAR-10 Batch 5:  Loss: 0.7326       Validation Accuracy: 0.623800
# Epoch 66, CIFAR-10 Batch 1:  Loss: 0.7744       Validation Accuracy: 0.622200
# Epoch 66, CIFAR-10 Batch 2:  Loss: 0.8037       Validation Accuracy: 0.610000
# Epoch 66, CIFAR-10 Batch 3:  Loss: 0.7882       Validation Accuracy: 0.618400
# Epoch 66, CIFAR-10 Batch 4:  Loss: 0.7581       Validation Accuracy: 0.617400
# Epoch 66, CIFAR-10 Batch 5:  Loss: 0.7439       Validation Accuracy: 0.614200
# Epoch 67, CIFAR-10 Batch 1:  Loss: 0.7883       Validation Accuracy: 0.617400
# Epoch 67, CIFAR-10 Batch 2:  Loss: 0.8049       Validation Accuracy: 0.622000
# Epoch 67, CIFAR-10 Batch 3:  Loss: 0.7959       Validation Accuracy: 0.615400
# Epoch 67, CIFAR-10 Batch 4:  Loss: 0.7440       Validation Accuracy: 0.619600
# Epoch 67, CIFAR-10 Batch 5:  Loss: 0.7287       Validation Accuracy: 0.619400
# Epoch 68, CIFAR-10 Batch 1:  Loss: 0.7774       Validation Accuracy: 0.620000
# Epoch 68, CIFAR-10 Batch 2:  Loss: 0.8155       Validation Accuracy: 0.612200
# Epoch 68, CIFAR-10 Batch 3:  Loss: 0.7825       Validation Accuracy: 0.621800
# Epoch 68, CIFAR-10 Batch 4:  Loss: 0.7581       Validation Accuracy: 0.622200
# Epoch 68, CIFAR-10 Batch 5:  Loss: 0.7409       Validation Accuracy: 0.623400
# Epoch 69, CIFAR-10 Batch 1:  Loss: 0.7581       Validation Accuracy: 0.625600
# Epoch 69, CIFAR-10 Batch 2:  Loss: 0.7874       Validation Accuracy: 0.618200
# Epoch 69, CIFAR-10 Batch 3:  Loss: 0.8023       Validation Accuracy: 0.617000
# Epoch 69, CIFAR-10 Batch 4:  Loss: 0.7397       Validation Accuracy: 0.628000
# Epoch 69, CIFAR-10 Batch 5:  Loss: 0.7178       Validation Accuracy: 0.628400
# Epoch 70, CIFAR-10 Batch 1:  Loss: 0.7615       Validation Accuracy: 0.617800
# Epoch 70, CIFAR-10 Batch 2:  Loss: 0.7822       Validation Accuracy: 0.625200
# Epoch 70, CIFAR-10 Batch 3:  Loss: 0.7818       Validation Accuracy: 0.628800
# Epoch 70, CIFAR-10 Batch 4:  Loss: 0.7175       Validation Accuracy: 0.632800
# Epoch 70, CIFAR-10 Batch 5:  Loss: 0.7063       Validation Accuracy: 0.625800
# Epoch 71, CIFAR-10 Batch 1:  Loss: 0.7472       Validation Accuracy: 0.625400
# Epoch 71, CIFAR-10 Batch 2:  Loss: 0.7606       Validation Accuracy: 0.623600
# Epoch 71, CIFAR-10 Batch 3:  Loss: 0.7570       Validation Accuracy: 0.631600
# Epoch 71, CIFAR-10 Batch 4:  Loss: 0.7083       Validation Accuracy: 0.627800
# Epoch 71, CIFAR-10 Batch 5:  Loss: 0.6940       Validation Accuracy: 0.624600
# Epoch 72, CIFAR-10 Batch 1:  Loss: 0.7399       Validation Accuracy: 0.630600
# Epoch 72, CIFAR-10 Batch 2:  Loss: 0.7557       Validation Accuracy: 0.626800
# Epoch 72, CIFAR-10 Batch 3:  Loss: 0.7532       Validation Accuracy: 0.631600
# Epoch 72, CIFAR-10 Batch 4:  Loss: 0.7051       Validation Accuracy: 0.631000
# Epoch 72, CIFAR-10 Batch 5:  Loss: 0.6917       Validation Accuracy: 0.628200
# Epoch 73, CIFAR-10 Batch 1:  Loss: 0.7413       Validation Accuracy: 0.622200
# Epoch 73, CIFAR-10 Batch 2:  Loss: 0.7603       Validation Accuracy: 0.625600
# Epoch 73, CIFAR-10 Batch 3:  Loss: 0.7570       Validation Accuracy: 0.627600
# Epoch 73, CIFAR-10 Batch 4:  Loss: 0.7072       Validation Accuracy: 0.627200
# Epoch 73, CIFAR-10 Batch 5:  Loss: 0.6864       Validation Accuracy: 0.623200
# Epoch 74, CIFAR-10 Batch 1:  Loss: 0.7281       Validation Accuracy: 0.624800
# Epoch 74, CIFAR-10 Batch 2:  Loss: 0.7459       Validation Accuracy: 0.630200
# Epoch 74, CIFAR-10 Batch 3:  Loss: 0.7491       Validation Accuracy: 0.626600
# Epoch 74, CIFAR-10 Batch 4:  Loss: 0.7011       Validation Accuracy: 0.623400
# Epoch 74, CIFAR-10 Batch 5:  Loss: 0.6942       Validation Accuracy: 0.628200
# Epoch 75, CIFAR-10 Batch 1:  Loss: 0.7279       Validation Accuracy: 0.628000
# Epoch 75, CIFAR-10 Batch 2:  Loss: 0.7617       Validation Accuracy: 0.620000
# Epoch 75, CIFAR-10 Batch 3:  Loss: 0.7443       Validation Accuracy: 0.625800
# Epoch 75, CIFAR-10 Batch 4:  Loss: 0.6907       Validation Accuracy: 0.630600
# Epoch 75, CIFAR-10 Batch 5:  Loss: 0.6827       Validation Accuracy: 0.627600
# Epoch 76, CIFAR-10 Batch 1:  Loss: 0.7194       Validation Accuracy: 0.633000
# Epoch 76, CIFAR-10 Batch 2:  Loss: 0.7406       Validation Accuracy: 0.630400
# Epoch 76, CIFAR-10 Batch 3:  Loss: 0.7427       Validation Accuracy: 0.627200
# Epoch 76, CIFAR-10 Batch 4:  Loss: 0.6940       Validation Accuracy: 0.628600
# Epoch 76, CIFAR-10 Batch 5:  Loss: 0.6587       Validation Accuracy: 0.629800
# Epoch 77, CIFAR-10 Batch 1:  Loss: 0.7160       Validation Accuracy: 0.631400
# Epoch 77, CIFAR-10 Batch 2:  Loss: 0.7122       Validation Accuracy: 0.633800
# Epoch 77, CIFAR-10 Batch 3:  Loss: 0.7316       Validation Accuracy: 0.631800
# Epoch 77, CIFAR-10 Batch 4:  Loss: 0.6855       Validation Accuracy: 0.632800
# Epoch 77, CIFAR-10 Batch 5:  Loss: 0.6658       Validation Accuracy: 0.640200
# Epoch 78, CIFAR-10 Batch 1:  Loss: 0.7066       Validation Accuracy: 0.631600
# Epoch 78, CIFAR-10 Batch 2:  Loss: 0.7225       Validation Accuracy: 0.627800
# Epoch 78, CIFAR-10 Batch 3:  Loss: 0.7196       Validation Accuracy: 0.625600
# Epoch 78, CIFAR-10 Batch 4:  Loss: 0.6784       Validation Accuracy: 0.632600
# Epoch 78, CIFAR-10 Batch 5:  Loss: 0.6646       Validation Accuracy: 0.623400
# Epoch 79, CIFAR-10 Batch 1:  Loss: 0.7010       Validation Accuracy: 0.629800
# Epoch 79, CIFAR-10 Batch 2:  Loss: 0.7020       Validation Accuracy: 0.632600
# Epoch 79, CIFAR-10 Batch 3:  Loss: 0.7089       Validation Accuracy: 0.631200
# Epoch 79, CIFAR-10 Batch 4:  Loss: 0.6708       Validation Accuracy: 0.632200
# Epoch 79, CIFAR-10 Batch 5:  Loss: 0.6804       Validation Accuracy: 0.622800
# Epoch 80, CIFAR-10 Batch 1:  Loss: 0.7228       Validation Accuracy: 0.620800
# Epoch 80, CIFAR-10 Batch 2:  Loss: 0.7358       Validation Accuracy: 0.620200
# Epoch 80, CIFAR-10 Batch 3:  Loss: 0.7049       Validation Accuracy: 0.632200
# Epoch 80, CIFAR-10 Batch 4:  Loss: 0.6655       Validation Accuracy: 0.631800
# Epoch 80, CIFAR-10 Batch 5:  Loss: 0.6334       Validation Accuracy: 0.632600
# Epoch 81, CIFAR-10 Batch 1:  Loss: 0.7056       Validation Accuracy: 0.624600
# Epoch 81, CIFAR-10 Batch 2:  Loss: 0.6955       Validation Accuracy: 0.631200
# Epoch 81, CIFAR-10 Batch 3:  Loss: 0.7012       Validation Accuracy: 0.638800
# Epoch 81, CIFAR-10 Batch 4:  Loss: 0.6667       Validation Accuracy: 0.630800
# Epoch 81, CIFAR-10 Batch 5:  Loss: 0.6452       Validation Accuracy: 0.629000
# Epoch 82, CIFAR-10 Batch 1:  Loss: 0.6886       Validation Accuracy: 0.629000
# Epoch 82, CIFAR-10 Batch 2:  Loss: 0.6781       Validation Accuracy: 0.630800
# Epoch 82, CIFAR-10 Batch 3:  Loss: 0.6860       Validation Accuracy: 0.625200
# Epoch 82, CIFAR-10 Batch 4:  Loss: 0.6473       Validation Accuracy: 0.631800
# Epoch 82, CIFAR-10 Batch 5:  Loss: 0.6398       Validation Accuracy: 0.635000
# Epoch 83, CIFAR-10 Batch 1:  Loss: 0.6959       Validation Accuracy: 0.630000
# Epoch 83, CIFAR-10 Batch 2:  Loss: 0.6848       Validation Accuracy: 0.639800
# Epoch 83, CIFAR-10 Batch 3:  Loss: 0.6862       Validation Accuracy: 0.630200
# Epoch 83, CIFAR-10 Batch 4:  Loss: 0.6646       Validation Accuracy: 0.632600
# Epoch 83, CIFAR-10 Batch 5:  Loss: 0.6308       Validation Accuracy: 0.632000
# Epoch 84, CIFAR-10 Batch 1:  Loss: 0.6874       Validation Accuracy: 0.637000
# Epoch 84, CIFAR-10 Batch 2:  Loss: 0.6906       Validation Accuracy: 0.632600
# Epoch 84, CIFAR-10 Batch 3:  Loss: 0.6908       Validation Accuracy: 0.623600
# Epoch 84, CIFAR-10 Batch 4:  Loss: 0.6460       Validation Accuracy: 0.637200
# Epoch 84, CIFAR-10 Batch 5:  Loss: 0.6456       Validation Accuracy: 0.630400
# Epoch 85, CIFAR-10 Batch 1:  Loss: 0.7150       Validation Accuracy: 0.618800
# Epoch 85, CIFAR-10 Batch 2:  Loss: 0.7179       Validation Accuracy: 0.628800
# Epoch 85, CIFAR-10 Batch 3:  Loss: 0.7303       Validation Accuracy: 0.612000
# Epoch 85, CIFAR-10 Batch 4:  Loss: 0.6576       Validation Accuracy: 0.638400
# Epoch 85, CIFAR-10 Batch 5:  Loss: 0.6706       Validation Accuracy: 0.617400
# Epoch 86, CIFAR-10 Batch 1:  Loss: 0.6901       Validation Accuracy: 0.635600
# Epoch 86, CIFAR-10 Batch 2:  Loss: 0.7405       Validation Accuracy: 0.611800
# Epoch 86, CIFAR-10 Batch 3:  Loss: 0.7020       Validation Accuracy: 0.631000
# Epoch 86, CIFAR-10 Batch 4:  Loss: 0.6735       Validation Accuracy: 0.633800
# Epoch 86, CIFAR-10 Batch 5:  Loss: 0.6336       Validation Accuracy: 0.627600
# Epoch 87, CIFAR-10 Batch 1:  Loss: 0.6536       Validation Accuracy: 0.642200
# Epoch 87, CIFAR-10 Batch 2:  Loss: 0.6795       Validation Accuracy: 0.628800
# Epoch 87, CIFAR-10 Batch 3:  Loss: 0.6633       Validation Accuracy: 0.639600
# Epoch 87, CIFAR-10 Batch 4:  Loss: 0.6617       Validation Accuracy: 0.631200
# Epoch 87, CIFAR-10 Batch 5:  Loss: 0.6456       Validation Accuracy: 0.624600
# Epoch 88, CIFAR-10 Batch 1:  Loss: 0.6900       Validation Accuracy: 0.624400
# Epoch 88, CIFAR-10 Batch 2:  Loss: 0.6880       Validation Accuracy: 0.633400
# Epoch 88, CIFAR-10 Batch 3:  Loss: 0.6752       Validation Accuracy: 0.641000
# Epoch 88, CIFAR-10 Batch 4:  Loss: 0.6325       Validation Accuracy: 0.639600
# Epoch 88, CIFAR-10 Batch 5:  Loss: 0.6006       Validation Accuracy: 0.639600
# Epoch 89, CIFAR-10 Batch 1:  Loss: 0.6606       Validation Accuracy: 0.633600
# Epoch 89, CIFAR-10 Batch 2:  Loss: 0.6798       Validation Accuracy: 0.633600
# Epoch 89, CIFAR-10 Batch 3:  Loss: 0.6602       Validation Accuracy: 0.644200
# Epoch 89, CIFAR-10 Batch 4:  Loss: 0.6341       Validation Accuracy: 0.639800
# Epoch 89, CIFAR-10 Batch 5:  Loss: 0.5845       Validation Accuracy: 0.639600
# Epoch 90, CIFAR-10 Batch 1:  Loss: 0.6416       Validation Accuracy: 0.634000
# Epoch 90, CIFAR-10 Batch 2:  Loss: 0.7018       Validation Accuracy: 0.615200
# Epoch 90, CIFAR-10 Batch 3:  Loss: 0.6620       Validation Accuracy: 0.630000
# Epoch 90, CIFAR-10 Batch 4:  Loss: 0.6541       Validation Accuracy: 0.634000
# Epoch 90, CIFAR-10 Batch 5:  Loss: 0.6054       Validation Accuracy: 0.637400
# Epoch 91, CIFAR-10 Batch 1:  Loss: 0.6343       Validation Accuracy: 0.636000
# Epoch 91, CIFAR-10 Batch 2:  Loss: 0.6710       Validation Accuracy: 0.628400
# Epoch 91, CIFAR-10 Batch 3:  Loss: 0.6670       Validation Accuracy: 0.633200
# Epoch 91, CIFAR-10 Batch 4:  Loss: 0.6627       Validation Accuracy: 0.633200
# Epoch 91, CIFAR-10 Batch 5:  Loss: 0.5996       Validation Accuracy: 0.636200
# Epoch 92, CIFAR-10 Batch 1:  Loss: 0.6447       Validation Accuracy: 0.640600
# Epoch 92, CIFAR-10 Batch 2:  Loss: 0.6793       Validation Accuracy: 0.626800
# Epoch 92, CIFAR-10 Batch 3:  Loss: 0.6767       Validation Accuracy: 0.628200
# Epoch 92, CIFAR-10 Batch 4:  Loss: 0.6311       Validation Accuracy: 0.631400
# Epoch 92, CIFAR-10 Batch 5:  Loss: 0.5989       Validation Accuracy: 0.637400
# Epoch 93, CIFAR-10 Batch 1:  Loss: 0.6406       Validation Accuracy: 0.633400
# Epoch 93, CIFAR-10 Batch 2:  Loss: 0.6621       Validation Accuracy: 0.629000
# Epoch 93, CIFAR-10 Batch 3:  Loss: 0.6507       Validation Accuracy: 0.635600
# Epoch 93, CIFAR-10 Batch 4:  Loss: 0.6248       Validation Accuracy: 0.638200
# Epoch 93, CIFAR-10 Batch 5:  Loss: 0.6027       Validation Accuracy: 0.636800
# Epoch 94, CIFAR-10 Batch 1:  Loss: 0.6330       Validation Accuracy: 0.629200
# Epoch 94, CIFAR-10 Batch 2:  Loss: 0.6511       Validation Accuracy: 0.635400
# Epoch 94, CIFAR-10 Batch 3:  Loss: 0.6520       Validation Accuracy: 0.633400
# Epoch 94, CIFAR-10 Batch 4:  Loss: 0.6333       Validation Accuracy: 0.629200
# Epoch 94, CIFAR-10 Batch 5:  Loss: 0.6134       Validation Accuracy: 0.628200
# Epoch 95, CIFAR-10 Batch 1:  Loss: 0.6878       Validation Accuracy: 0.621200
# Epoch 95, CIFAR-10 Batch 2:  Loss: 0.7123       Validation Accuracy: 0.621400
# Epoch 95, CIFAR-10 Batch 3:  Loss: 0.6876       Validation Accuracy: 0.631000
# Epoch 95, CIFAR-10 Batch 4:  Loss: 0.6698       Validation Accuracy: 0.629600
# Epoch 95, CIFAR-10 Batch 5:  Loss: 0.6240       Validation Accuracy: 0.639600
# Epoch 96, CIFAR-10 Batch 1:  Loss: 0.6031       Validation Accuracy: 0.643800
# Epoch 96, CIFAR-10 Batch 2:  Loss: 0.6535       Validation Accuracy: 0.636400
# Epoch 96, CIFAR-10 Batch 3:  Loss: 0.6499       Validation Accuracy: 0.639000
# Epoch 96, CIFAR-10 Batch 4:  Loss: 0.5844       Validation Accuracy: 0.645000
# Epoch 96, CIFAR-10 Batch 5:  Loss: 0.5724       Validation Accuracy: 0.646200
# Epoch 97, CIFAR-10 Batch 1:  Loss: 0.5771       Validation Accuracy: 0.648600
# Epoch 97, CIFAR-10 Batch 2:  Loss: 0.6236       Validation Accuracy: 0.644400
# Epoch 97, CIFAR-10 Batch 3:  Loss: 0.6113       Validation Accuracy: 0.642200
# Epoch 97, CIFAR-10 Batch 4:  Loss: 0.5845       Validation Accuracy: 0.638400
# Epoch 97, CIFAR-10 Batch 5:  Loss: 0.5638       Validation Accuracy: 0.646600
# Epoch 98, CIFAR-10 Batch 1:  Loss: 0.5680       Validation Accuracy: 0.648000
# Epoch 98, CIFAR-10 Batch 2:  Loss: 0.6282       Validation Accuracy: 0.637800
# Epoch 98, CIFAR-10 Batch 3:  Loss: 0.6054       Validation Accuracy: 0.647800
# Epoch 98, CIFAR-10 Batch 4:  Loss: 0.6084       Validation Accuracy: 0.634000
# Epoch 98, CIFAR-10 Batch 5:  Loss: 0.5756       Validation Accuracy: 0.635000
# Epoch 99, CIFAR-10 Batch 1:  Loss: 0.5818       Validation Accuracy: 0.647600
# Epoch 99, CIFAR-10 Batch 2:  Loss: 0.6118       Validation Accuracy: 0.647000
# Epoch 99, CIFAR-10 Batch 3:  Loss: 0.6072       Validation Accuracy: 0.647000
# Epoch 99, CIFAR-10 Batch 4:  Loss: 0.5893       Validation Accuracy: 0.639000
# Epoch 99, CIFAR-10 Batch 5:  Loss: 0.5515       Validation Accuracy: 0.646000
# Epoch 100, CIFAR-10 Batch 1:  Loss: 0.5695       Validation Accuracy: 0.641000
# Epoch 100, CIFAR-10 Batch 2:  Loss: 0.6097       Validation Accuracy: 0.645200
# Epoch 100, CIFAR-10 Batch 3:  Loss: 0.6072       Validation Accuracy: 0.646600
# Epoch 100, CIFAR-10 Batch 4:  Loss: 0.5706       Validation Accuracy: 0.637800
# Epoch 100, CIFAR-10 Batch 5:  Loss: 0.5603       Validation Accuracy: 0.642400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6508261919021606

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
